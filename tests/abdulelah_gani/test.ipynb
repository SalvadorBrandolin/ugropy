# %%
from ugropy import get_groups, abdulelah_gani_primary

import pandas as pd

import numpy as np

# %%
df = pd.read_csv("dataset/Tm_results_GC.csv", index_col="SMILES")

df.columns = [int(col) if col.isdigit() else col for col in df.columns]

# %%
def get_primary_groups_from_df(smiles):
    row = df.loc[smiles, np.linspace(1, 220, 220, dtype=int)]
    print(row)
    row.replace(0.0, np.nan, inplace=True)
    row.dropna(inplace=True)

    groups = row.to_dict()

    for group in groups.keys():
        group_name = abdulelah_gani_primary.subgroups[abdulelah_gani_primary.subgroups["group_number"] == group].index[0]

        groups[group_name] = groups.pop(group)

    return groups

# %%
get_primary_groups_from_df("COC(=O)COc1nc(F)c(Cl)c(N)c1Cl")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_primary_groups_from_df("COC(=O)COc1nc(F)c(Cl)c(N)c1Cl")
#
# Cell In[3], line 9, in get_primary_groups_from_df(smiles)
#       6 groups = row.to_dict()
#       8 for group in groups.keys():
# ----> 9     group_name = abdulelah_gani_primary.subgroups[abdulelah_gani_primary.subgroups["group_number"] == group].index[0]
#      11     groups[group_name] = groups.pop(group)
#      13 return groups
#
# File ~/.virtualenvs/ugropy/lib/python3.10/site-packages/pandas/core/indexes/base.py:5385, in Index.__getitem__(self, key)
#    5382 if is_integer(key) or is_float(key):
#    5383     # GH#44051 exclude bool, which would return a 2d ndarray
#    5384     key = com.cast_scalar_indexer(key)
# -> 5385     return getitem(key)
#    5387 if isinstance(key, slice):
#    5388     # This case is separated from the conditional above to avoid
#    5389     # pessimization com.is_bool_indexer and ndim checks.
#    5390     return self._getitem_slice(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df
# Out:
#                                                     Unnamed: 0  Experimental  \
# SMILES
# O=C(N)Nc1ccc(C)cc1                                           0        456.15
# OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C                 1        391.15
# COC(=O)COc1nc(F)c(Cl)c(N)c1Cl                                2        331.35
# O=C(O)CNCP(=O)(O)O                                           3        533.15
# O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C               4        438.15
# ...                                                        ...           ...
# CC(C(=O)NCC(=O)O)S                                        9244        372.15
# C1=CC=C(C=C1)C(C2=CC=CC=C2)(C3=CC=CC=C3)SC[C@@H...        9245        455.65
# C1=CC=C(C=C1)CSC[C@@H](C(=O)O)N                           9246        487.15
# C(CC(=O)O)[C@@H](C(=O)[O-Na+])N                           9247        505.45
# COC1=CC=C(C=C1)C[C@@H](C(=O)O)N                           9248        533.15
#
#                                                     Prediction     stdev  1  \
# SMILES
# O=C(N)Nc1ccc(C)cc1                                  456.148325  0.331552  0
# OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C        391.150180  0.331039  3
# COC(=O)COc1nc(F)c(Cl)c(N)c1Cl                       331.350751  0.331066  1
# O=C(O)CNCP(=O)(O)O                                  497.899603  0.235616  0
# O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C      438.149909  0.331153  1
# ...                                                        ...       ... ..
# CC(C(=O)NCC(=O)O)S                                  370.650772  0.235746  1
# C1=CC=C(C=C1)C(C2=CC=CC=C2)(C3=CC=CC=C3)SC[C@@H...  455.399963  0.234408  0
# C1=CC=C(C=C1)CSC[C@@H](C(=O)O)N                     487.149480  0.331540  0
# C(CC(=O)O)[C@@H](C(=O)[O-Na+])N                     505.449310  0.330868  0
# COC1=CC=C(C=C1)C[C@@H](C(=O)O)N                     533.149584  0.331247  1
#
#                                                     2  3  4  5  6  ...  415  \
# SMILES                                                             ...
# O=C(N)Nc1ccc(C)cc1                                  0  0  0  0  0  ...    0
# OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C        1  2  1  0  0  ...    0
# COC(=O)COc1nc(F)c(Cl)c(N)c1Cl                       0  0  0  0  0  ...    0
# O=C(O)CNCP(=O)(O)O                                  1  0  0  0  0  ...    0
# O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C      0  0  0  0  0  ...    0
# ...                                                .. .. .. .. ..  ...  ...
# CC(C(=O)NCC(=O)O)S                                  0  0  0  0  0  ...    0
# C1=CC=C(C=C1)C(C2=CC=CC=C2)(C3=CC=CC=C3)SC[C@@H...  0  0  0  0  0  ...    0
# C1=CC=C(C=C1)CSC[C@@H](C(=O)O)N                     0  0  0  0  0  ...    0
# C(CC(=O)O)[C@@H](C(=O)[O-Na+])N                     2  0  0  0  0  ...    0
# COC1=CC=C(C=C1)C[C@@H](C(=O)O)N                     0  0  0  0  0  ...    0
#
#                                                     416  417  418  419  420  \
# SMILES
# O=C(N)Nc1ccc(C)cc1                                    0    0    0    0    0
# OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C          0    0    0    0    0
# COC(=O)COc1nc(F)c(Cl)c(N)c1Cl                         0    0    0    0    0
# O=C(O)CNCP(=O)(O)O                                    0    0    0    0    0
# O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C        0    0    0    0    0
# ...                                                 ...  ...  ...  ...  ...
# CC(C(=O)NCC(=O)O)S                                    0    0    0    0    0
# C1=CC=C(C=C1)C(C2=CC=CC=C2)(C3=CC=CC=C3)SC[C@@H...    0    0    0    0    0
# C1=CC=C(C=C1)CSC[C@@H](C(=O)O)N                       0    0    0    0    0
# C(CC(=O)O)[C@@H](C(=O)[O-Na+])N                       0    0    0    0    0
# COC1=CC=C(C=C1)C[C@@H](C(=O)O)N                       0    0    0    0    0
#
#                                                     421  422  423  424
# SMILES
# O=C(N)Nc1ccc(C)cc1                                    0    0    0    0
# OCC(C(Oc1ccc(cc1)c2ccccc2)N3C=NC=N3)C(C)(C)C          0    0    0    0
# COC(=O)COc1nc(F)c(Cl)c(N)c1Cl                         0    0    0    0
# O=C(O)CNCP(=O)(O)O                                    0    0    0    0
# O=N(=O)c1cc(ccc1C(=O)C2C(=O)CCCC2=O)S(=O)(=O)C        0    0    0    0
# ...                                                 ...  ...  ...  ...
# CC(C(=O)NCC(=O)O)S                                    0    0    0    0
# C1=CC=C(C=C1)C(C2=CC=CC=C2)(C3=CC=CC=C3)SC[C@@H...    0    0    0    0
# C1=CC=C(C=C1)CSC[C@@H](C(=O)O)N                       0    0    0    0
# C(CC(=O)O)[C@@H](C(=O)[O-Na+])N                       0    0    0    0
# COC1=CC=C(C=C1)C[C@@H](C(=O)O)N                       0    0    0    0
#
# [9249 rows x 428 columns]
